# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

rawData = pd.read_csv('123.txt', names=['Fraction','R','G','B'])
rawData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Fraction  10 non-null     float64
#  1   R         10 non-null     float64
#  2   G         10 non-null     float64
#  3   B         10 non-null     float64
# dtypes: float64(4)
# memory usage: 448.0 bytes

# %%
#rawData.head()

rawData.plot()

# %%
rawData = rawData.sort_values(["Fraction"], ascending=[False])
rawData.head()
# Out:
#    Fraction      R      G      B
# 0  0.287180  252.0  251.0  249.0
# 2  0.124182  135.0   46.0   25.0
# 5  0.035396   78.0   39.0   31.0
# 1  0.010857   56.0   21.0   16.0
# 7  0.009369   60.0   46.0   43.0

# %%
rawData.plot()
